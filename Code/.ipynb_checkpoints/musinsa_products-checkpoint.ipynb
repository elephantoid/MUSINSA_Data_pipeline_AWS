# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import requests
import re

# %%
def no_space(text):
    text1 = re.sub("&nbsp; | &nbsp;|\n|\t|\r","",text)
    text2 = re.sub("\n\n","",text1)
    return text2

# %%
def get_text(url):
    item_name_list=[]
    item_price_list=[]
    try:
        html= urlopen(url)
        bs= BeautifulSoup(html, "html.parser")
        
        
        title = bs.findAll('p', {"class":"list_info"}, recurisive=False)
        for i in title:
            text = no_space(i.get_text())
            item_name_list.append(text)
            print(text)
            
        price = bs.findAll('p', {"class":"price"})
        for i in price:
            text2 = no_space(i.get_text())
            item_price_list.append(text2)
            print(text2)
    except:
        print("실패")

# %%
def get_title(url):
    html= urlopen(url)
    bs= BeautifulSoup(html, "html.parser")
    i=0
    item_name_list=[]
    for item_name in bs.find_all('p', {"class":"list_info"}):
        item_name_list.append(no_space(item_name.get_text()))
    return item_name_list

# %%
#실제 카테고리별 번호는 001010, 002003 ...
CategoryId_list = [
    # 상의 0~7
    ['반팔 티셔츠', 1001],
    ['셔츠/블라우스', 1002],
    ['피케/카라 티셔츠', 1003],
    ['후드 티셔츠', 1004],
    ['맨투맨/스웨트셔츠',1005],
    ['니트/스웨터', 1006],
    ['긴팔 티셔츠', 1010],
    ['민소매 티셔츠', 1011],
    # 아우터 8~15
    ['슈트/블레이저', 2003],
    ['후드 집업', 2022],
    ['블루종/MA-1', 2001],
    ['환절기 코트', 2008],
    ['래더/라이더스 재킷', 2002],
    ['숏패딩/숏헤비 아우터', 2012],
    ['롱패딩/롱헤비 아우터', 2013],
    ['기타 아우터', 2015],
    # 하의 16~21
    ['데님 팬츠',3002],
    ['슈트 팬츠/슬랙스', 3008],
    ['코튼 팬츠', 3007],
    ['트레이닝/조거 팬츠',3004],
    ['숏 팬츠', 3009],
    ['레깅스', 3005],
    # 원피스 22~24
    ['미니 원피스', 20006],
    ['미디 원피스', 20007],
    ['맥시 원피스', 20008],
    # 스커트 25~27
    ['미니스커트', 22001],
    ['미디스커트', 22002],
    ['롱 스커트', 22003]
    
]

# %%
a= list(str(CategoryId_list[i][1]) for i in range(len(CategoryId_list)))
print(a)
# Out:
# ['1001', '1002', '1003', '1004', '1005', '1006', '1010', '1011', '2003', '2022', '2001', '2008', '2002', '2012', '2013', '2015', '3002', '3008', '3007', '3004', '3009', '3005', '20006', '20007', '20008', '22001', '22002', '22003']

# %%
if a[27].split('2200')[0] == '':
    print('Y')
else:
    print('N')
# Out:
# Y

# %%
len(CategoryId_list)
# Out:
# 28

# %%
import time
time.sleep(3)

# %%
#import pymysql

#db = pymysql.connect(host='localhost', user='root', password='root', db='musinsa')
#curs = db.cursor()
item_name_list=[]
item_price_list=[]
item_brand_list=[]
item_type_list=[]
for i in range(len(CategoryId_list)):
    CategoryId = str(CategoryId_list[i][1])

    for k in range(1,6):
        Limit=k
        if CategoryId.split('2000')[0] =='':
            url= f"https://search.musinsa.com/category/"\
        +'0'+ CategoryId+'?d_cat_cd='+CategoryId+f"&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page={Limit}"+'&display_cnt=90'
        elif CategoryId.split('2200')[0]=='':
            url= f"https://search.musinsa.com/category/"\
        +'0'+ CategoryId+'?d_cat_cd='+CategoryId+f"&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page={Limit}"+'&display_cnt=90'
        else:
            url= f"https://search.musinsa.com/category/"\
        +'00'+ CategoryId+'?d_cat_cd='+CategoryId+f"&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page={Limit}"+'&display_cnt=90'
    #실제 제품의 항목번호를 위하여 00을 추가, 판매순으로 sorting
        html= urlopen(url)
        bs= BeautifulSoup(html, "html.parser")
        
        for item_name in bs.find_all('p', {"class":"list_info"}):
            item_name_list.append(no_space(item_name.get_text()).replace(" ", ""))
            item_type_list.append(CategoryId_list[i][0])
#             print(i, item_name_list)
#             time.sleep(3)
        
        for item_price in bs.find_all('p',{"class":"price"}):
            item_price=no_space(item_price.get_text())
            item_price=item_price.replace(" ", "")
            item_price=item_price.replace("원", '.')
            item_price=item_price.split('.')
            if len(item_price)>2:
                item_price_list.append(item_price[1])
            else:
                item_price_list.append(item_price[0])
                
#             print(i, item_price_list)
#             time.sleep(3)
        
        for item_brand in bs.find_all('p',{"class":"item_title"}):
            item_brand_list.append(no_space(item_brand.get_text()))
#             print(i, item_brand_list)

#         for j in range(len(item_name_list)):
#             query = "INSERT INTO products(name,brand, price, type, created_date) VALUES('"\
#             + item_name_list[j]+"','"+item_brand_list[j]+"',"+item_price_list[j].replace(',','')+", '"\
#             + CategoryId_list[i][0]+"', curdate());"
#             time.sleep(3)
#             curs.execute(query)
# db.commit()
# db.close

# %%
item_price_list
# Out:
# ['11900',
#  '13900',
#  '19500',
#  '11900',
#  '34400',
#  '10900',
#  '35000',
#  '24500',
#  '17800',
#  '19500',
#  '18000',
#  '19900',
#  '10900',
#  '12900',
#  '21000',
#  '23400',
#  '29700',
#  '28800',
#  '19500',
#  '10000',
#  '23400',
#  '19900',
#  '21500',
#  '21000',
#  '14900',
#  '23400',
#  '21000',
#  '21800',
#  '37800',
#  '17900',
#  '25350',
#  '21000',
#  '25350',
#  '21000',
#  '15900',
#  '21000',
#  '17900',
#  '12900',
#  '15900',
#  '23400',
#  '23400',
#  '23400',
#  '21000',
#  '25350',
#  '21900',
#  '19500',
#  '8900',
#  '39800',
#  '32000',
#  '18900',
#  '15600',
#  '21000',
#  '39000',
#  '24500',
#  '11900',
#  '24500',
#  '27600',
#  '21900',
#  '23400',
#  '24500',
#  '9900',
#  '39000',
#  '23400',
#  '27900',
#  '24500',
#  '11890',
#  '23400',
#  '23400',
#  '39000',
#  '16800',
#  '21900',
#  '28000',
#  '24000',
#  '27300',
#  '15990',
#  '39000',
#  '35900',
#  '11900',
#  '14900',
#  '25350',
#  '25900',
#  '42900',
#  '15600',
#  '19900',
#  '28700',
#  '29000',
#  '11900',
#  '19500',
#  '23100',
#  '28050',
#  '17900',
#  '19500',
#  '21000',
#  '32000',
#  '27300',
#  '42000',
#  '27300',
#  '31000',
#  '34400',
#  '8290',
#  '39000',
#  '23400',
#  '28900',
#  '23800',
#  '45000',
#  '14900',
#  '31000',
#  '11590',
#  '18900',
#  '24500',
#  '29800',
#  '23100',
#  '23400',
#  '29400',
#  '23400',
#  '23400',
#  '21000',
#  '19800',
#  '39000',
#  '24500',
#  '58900',
#  '42000',
#  '39000',
#  '23400',
#  '46400',
#  '29800',
#  '19800',
#  '23400',
#  '23100',
#  '25350',
#  '39000',
#  '17900',
#  '16740',
#  '14900',
#  '6900',
#  '25800',
#  '37200',
#  '7900',
#  '39900',
#  '9900',
#  '39900',
#  '27900',
#  '28050',
#  '45000',
#  '12900',
#  '36550',
#  '36800',
#  '12450',
#  '29900',
#  '42000',
#  '27800',
#  '21000',
#  '39000',
#  '7900',
#  '15990',
#  '19900',
#  '10890',
#  '27300',
#  '24500',
#  '21000',
#  '24500',
#  '23400',
#  '28000',
#  '13900',
#  '29800',
#  '27300',
#  '39000',
#  '24650',
#  '33900',
#  '11890',
#  '29400',
#  '29000',
#  '11900',
#  '28800',
#  '12900',
#  '8290',
#  '28800',
#  '39800',
#  '21000',
#  '22500',
#  '13900',
#  '12900',
#  '18900',
#  '21000',
#  '13900',
#  '34800',
#  '29400',
#  '29900',
#  '15900',
#  '29500',
#  '25350',
#  '23400',
#  '28900',
#  '31600',
#  '28700',
#  '7900',
#  '24000',
#  '13900',
#  '21000',
#  '39000',
#  '14900',
#  '10900',
#  '9900',
#  '8290',
#  '37200',
#  '13900',
#  '23400',
#  '23400',
#  '11900',
#  '45000',
#  '28000',
#  '9790',
#  '7900',
#  '8900',
#  '29000',
#  '10690',
#  '25350',
#  '32000',
#  '31200',
#  '10890',
#  '27900',
#  '23400',
#  '31000',
#  '42000',
#  '30900',
#  '25350',
#  '10090',
#  '25200',
#  '23800',
#  '23400',
#  '27200',
#  '27300',
#  '6900',
#  '22900',
#  '29900',
#  '31500',
#  '32000',
#  '18900',
#  '28800',
#  '27300',
#  '22400',
#  '23400',
#  '23400',
#  '27900',
#  '29250',
#  '23800',
#  '19900',
#  '26100',
#  '32700',
#  '15920',
#  '9490',
#  '10900',
#  '26700',
#  '45000',
#  '19900',
#  '25200',
#  '19500',
#  '31200',
#  '25350',
#  '33600',
#  '24900',
#  '23200',
#  '11000',
#  '11900',
#  '12900',
#  '21900',
#  '39000',
#  '21000',
#  '9900',
#  '27900',
#  '34300',
#  '21000',
#  '22400',
#  '19900',
#  '23400',
#  '27300',
#  '32000',
#  '21000',
#  '39000',
#  '15900',
#  '21900',
#  '23400',
#  '11900',
#  '25800',
#  '27300',
#  '28000',
#  '41000',
#  '23400',
#  '25500',
#  '18900',
#  '10900',
#  '23400',
#  '9590',
#  '10900',
#  '24650',
#  '29400',
#  '8290',
#  '15900',
#  '15900',
#  '37800',
#  '29800',
#  '23920',
#  '25500',
#  '16090',
#  '27300',
#  '23400',
#  '39000',
#  '29250',
#  '39000',
#  '27600',
#  '24650',
#  '10900',
#  '29900',
#  '26100',
#  '9900',
#  '11900',
#  '49000',
#  '10890',
#  '31000',
#  '21000',
#  '18900',
#  '29000',
#  '7900',
#  '11900',
#  '49000',
#  '17550',
#  '23400',
#  '23800',
#  '10690',
#  '26500',
#  '9900',
#  '10090',
#  '23400',
#  '19500',
#  '11900',
#  '11900',
#  '39000',
#  '24650',
#  '48000',
#  '27300',
#  '29400',
#  '17900',
#  '23400',
#  '33600',
#  '11900',
#  '23400',
#  '27000',
#  '18900',
#  '15900',
#  '28900',
#  '29900',
#  '11700',
#  '55100',
#  '47200',
#  '47200',
#  '19500',
#  '39200',
#  '39200',
#  '47200',
#  '39200',
#  '40200',
#  '40200',
#  '41500',
#  '58650',
#  '24900',
#  '38900',
#  '29700',
#  '24900',
#  '59700',
#  '42000',
#  '41500',
#  '43900',
#  '41500',
#  '36000',
#  '40200',
#  '27900',
#  '34500',
#  '43900',
#  '48000',
#  '23900',
#  '55200',
#  '42000',
#  '37600',
#  '40200',
#  '23900',
#  '29900',
#  '24900',
#  '41500',
#  '37260',
#  '23900',
#  '37600',
#  '43900',
#  '37600',
#  '42000',
#  '41500',
#  '24900',
#  '41500',
#  '37260',
#  '23900',
#  '34500',
#  '36000',
#  '36900',
#  '23900',
#  '30100',
#  '47200',
#  '37600',
#  '55900',
#  '30020',
#  '48000',
#  '37600',
#  '40200',
#  '32040',
#  '33600',
#  '55200',
#  '25900',
#  '37600',
#  '34900',
#  '88000',
#  '40200',
#  '42000',
#  '30100',
#  '36000',
#  '35200',
#  '39000',
#  '59700',
#  '21490',
#  '27900',
#  '24900',
#  '40200',
#  '61200',
#  '24900',
#  '34400',
#  '30000',
#  '28900',
#  '35900',
#  '24900',
#  '27900',
#  '30100',
#  '35900',
#  '63200',
#  '21590',
#  '25960',
#  '31080',
#  '36900',
#  '26220',
#  '41500',
#  '59000',
#  '41500',
#  '27600',
#  '48000',
#  '23900',
#  '35000',
#  '40200',
#  '35000',
#  '59700',
#  '59000',
#  '41300',
#  '23900',
#  '23900',
#  '59700',
#  '40200',
#  '23900',
#  '27900',
#  '26100',
#  '36900',
#  '42000',
#  '23900',
#  '24900',
#  '24690',
#  '34900',
#  '25960',
#  '88000',
#  '47200',
#  '41500',
#  '38700',
#  '53100',
#  '49900',
#  '41300',
#  '19900',
#  '48000',
#  '21500',
#  '64000',
#  '28800',
#  '43400',
#  '40200',
#  '36900',
#  '34510',
#  '40200',
#  '53100',
#  '24900',
#  '88000',
#  '34500',
#  '59700',
#  '27900',
#  '62900',
#  '34500',
#  '63200',
#  '68400',
#  '46800',
#  '58650',
#  '37600',
#  '57600',
#  '39600',
#  '42000',
#  '58900',
#  '41500',
#  '42000',
#  '41300',
#  '31850',
#  '29700',
#  '66800',
#  '29900',
#  '60800',
#  '41300',
#  '131100',
#  '150100',
#  '140600',
#  '79200',
#  '51200',
#  '35400',
#  '79200',
#  '52000',
#  '39800',
#  '38700',
#  '80100',
#  '61200',
#  '49000',
#  '69350',
#  '62100',
#  '80100',
#  '24900',
#  '35900',
#  '239000',
#  '80100',
#  '62100',
#  '89000',
#  '24900',
#  '49000',
#  '49000',
#  '38700',
#  '49000',
#  '64000',
#  '64000',
#  '59200',
#  '35200',
#  '199000',
#  '27900',
#  '37600',
#  '39000',
#  '39000',
#  '30100',
#  '49500',
#  '58650',
#  '39000',
#  '39000',
#  '39000',
#  '43000',
#  '53100',
#  '54000',
#  '54000',
#  '54000',
#  '88200',
#  '54000',
#  '42000',
#  '55000',
#  '54000',
#  '54000',
#  '55000',
#  '55000',
#  '48600',
#  '48600',
#  '48600',
#  '89500',
#  '48600',
#  '48600',
#  '49800',
#  '49800',
#  '48600',
#  '43000',
#  '48600',
#  '48600',
#  '75050',
#  '48600',
#  '49800',
#  '48600',
#  '75050',
#  '48600',
#  '48600',
#  '87500',
#  '55000',
#  '49800',
#  '48600',
#  '48600',
#  '48600',
#  '89500',
#  '55000',
#  '48600',
#  '48000',
#  '29900',
#  '42000',
#  '88200',
#  '42000',
#  '42000',
#  '39000',
#  '29900',
#  '39000',
#  '39000',
#  '43000',
#  '29900',
#  '39800',
#  '48000',
#  '43000',
#  '36000',
#  '43000',
#  '43000',
#  '49500',
#  '49500',
#  '41500',
#  '169000',
#  '55200',
#  '159000',
#  '169000',
#  '47300',
#  '69000',
#  '55200',
#  '169000',
#  '106000',
#  '159000',
#  '169000',
#  '96000',
#  '47300',
#  '47300',
#  '49800',
#  '44800',
#  '47300',
#  '49800',
#  '49800',
#  '47300',
#  '53500',
#  '44800',
#  '47300',
#  '47300',
#  '44800',
#  '47300',
#  '47300',
#  '169000',
#  '53500',
#  '44800',
#  '47300',
#  '47300',
#  '44800',
#  '44800',
#  '47300',
#  '169000',
#  '49800',
#  '44800',
#  '68000',
#  '47300',
#  '47300',
#  '49800',
#  '44800',
#  '44800',
#  '80750',
#  '47300',
#  '169000',
#  '49800',
#  '49800',
#  '69000',
#  '66000',
#  '86000',
#  '68000',
#  '68000',
#  '62000',
#  '56500',
#  '57000',
#  '55200',
#  '57000',
#  '56500',
#  '55200',
#  '46400',
#  '56500',
#  '57000',
#  '62000',
#  '56000',
#  '39000',
#  '55200',
#  '62000',
#  '39800',
#  '42000',
#  '83900',
#  '89000',
#  '89000',
#  '34200',
#  '35000',
#  '125100',
#  '59250',
#  '125100',
#  '58800',
#  '49900',
#  '75600',
#  '41300',
#  '67500',
#  '19800',
#  '175000',
#  '159000',
#  '139000',
#  '175000',
#  '175000',
#  '159000',
#  '159000',
#  '159000',
#  '43500',
#  '47300',
#  '49800',
#  '67500',
#  '43500',
#  '49800',
#  '67500',
#  '124000',
#  '129000',
#  '20690',
#  '34900',
#  '34300',
#  '38700',
#  '34900',
#  '39900',
#  '28000',
#  '34900',
#  '29400',
#  '28000',
#  '25390',
#  '22290',
#  '29400',
#  '16690',
#  '34900',
#  '29400',
#  '28900',
#  '34300',
#  '34900',
#  '23890',
#  '34900',
#  '38350',
#  '35700',
#  '20690',
#  '20690',
#  '29400',
#  '79200',
#  '55200',
#  '132300',
#  '20690',
#  '19900',
#  '34900',
#  '35400',
#  '48800',
#  '48800',
#  '28400',
#  '79000',
#  '79000',
#  '48800',
#  '68800',
#  '59200',
#  '87000',
#  '48800',
#  '48800',
#  '59200',
#  '48800',
#  '68800',
#  '59200',
#  '34900',
#  '179000',
#  '179000',
#  '34300',
#  '179000',
#  '179000',
#  '179000',
#  '58800',
#  '16690',
#  '55200',
#  '16690',
#  '48000',
#  '48000',
#  '48000',
#  '79000',
#  '99000',
#  '69900',
#  '99000',
#  '39900',
#  '39900',
#  '39900',
#  '39900',
#  '39900',
#  '132300',
#  '29400',
#  '118000',
#  '118000',
#  '34900',
#  '39000',
#  '53100',
#  '39900',
#  '39900',
#  '39900',
#  '53100',
#  '28000',
#  '26890',
#  '28100',
#  '20690',
#  '66600',
#  '58650',
#  '34200',
#  '66600',
#  '109000',
#  '169000',
#  '109000',
#  '53200',
#  '20690',
#  '29400',
#  '66600',
#  '56050',
#  '62100',
#  '169000',
#  '65570',
#  '65570',
#  '56050',
#  '55200',
#  '22290',
#  '58650',
#  '53200',
#  '109800',
#  '29400',
#  '99000',
#  '43000',
#  '53200',
#  '56050',
#  '99000',
#  '109000',
#  '36290',
#  '25900',
#  '53900',
#  '17640',
#  '58650',
#  '62100',
#  '19000',
#  '99000',
#  '99000',
#  '34900',
#  '20690',
#  '43200',
#  '28000',
#  '39900',
#  '34900',
#  '43200',
#  '129000',
#  '159000',
#  '29400',
#  '49400',
#  '157000',
#  '129000',
#  '125000',
#  '43700',
#  '28900',
#  '99000',
#  '28000',
#  '39900',
#  '109000',
#  '109000',
#  '96500',
#  '138800',
#  '138800',
#  '16690',
#  '79200',
#  '43200',
#  '99000',
#  '25900',
#  '66600',
#  '35400',
#  '55200',
#  '94050',
#  '179000',
#  '178000',
#  '178000',
#  '179000',
#  '47400',
#  '58650',
#  '129000',
#  '43200',
#  '169000',
#  '71100',
#  '58650',
#  '58650',
#  '109000',
#  '187000',
#  '187000',
#  '187000',
#  '179000',
#  '179000',
#  '179000',
#  '179000',
#  '159000',
#  '159000',
#  '159000',
#  '319000',
#  '39900',
#  '66600',
#  '58650',
#  '84550',
#  '38700',
#  '34900',
#  '58650',
#  '299000',
#  '279000',
#  '259000',
#  '259000',
#  '109000',
#  '109000',
#  '31500',
#  '79900',
#  '79900',
#  '259000',
#  '109000',
#  '109000',
#  '79900',
#  '58650',
#  '25900',
#  '169000',
#  '71100',
#  '20690',
#  '16690',
#  '79900',
#  '109000',
#  '69000',
#  '69000',
#  '109000',
#  '69000',
#  '58500',
#  '38700',
#  '58500',
#  '248000',
#  '22290',
#  '259000',
#  '38700',
#  '109000',
#  '38700',
#  '299000',
#  '29400',
#  '55200',
#  '55200',
#  '44820',
#  '58000',
#  '170000',
#  '170000',
#  '107100',
#  '107100',
#  '20690',
#  '39900',
#  '109000',
#  '87000',
#  '87000',
#  '107100',
#  '39900',
#  '11900',
#  '299000',
#  '299000',
#  '279000',
#  '94050',
#  '118750',
#  '259000',
#  '16690',
#  '58000',
#  '55900',
#  '44100',
#  '44100',
#  '106200',
#  '28000',
#  '59000',
#  '29400',
#  '42000',
#  '106200',
#  '29490',
#  '64800',
#  '139000',
#  '109000',
#  '139000',
#  '34900',
#  '44910',
#  '62100',
#  '116100',
#  '106000',
#  '16690',
#  '106000',
#  '106000',
#  '16690',
#  '106000',
#  '106000',
#  '43200',
#  '65000',
#  '65000',
#  '37900',
#  '71100',
#  '105000',
#  '99000',
#  ...]

# %%
# import pandas as pd
# columns=['item_name_list','item_price_list','item_brand_list','item_type_list']
# item_name_list_df= pd.DataFrame(item_name_list)
# item_price_list_df=pd.DataFrame(item_price_list)
# item_brand_list_df=pd.DataFrame(item_brand_list)
# item_type_list_df=pd.DataFrame(item_type_list)
# df= pd.concat(item_name_list_df, item_price_list_df, item_brand_list_df, item_type_list_df)
# print(df.head())

# %%
print(len(item_name_list))
print(len(item_price_list))
print(len(item_brand_list))
print(len(item_type_list))
# Out:
# 10080
# 10080
# 10182
# 10080

# %%
print(item_name_list[1],'\n',
     item_price_list[1],'\n',
     item_brand_list[1],'\n',
     item_type_list[1])
# Out:
# 릴렉스핏크루넥반팔티셔츠[화이트]
#  11,900
#  무신사 스탠다드
#  반팔 티셔츠

# %%
for i in range(len(item_name_list)):
    item_name_list[i]=item_name_list[i].replace(" ", "")
item_name_list
# Out:
# ['레이어드크루넥반팔티셔츠_긴기장[화이트]',
#  '릴렉스핏크루넥반팔티셔츠[화이트]',
#  '베이식크루넥반팔티셔츠[화이트]',
#  '릴렉스핏크루넥반팔티셔츠[블랙]',
#  'EMBROIDERYHANDSOMEDANTEEWHITE',
#  '021541레이어드반팔티셔츠(2pck)',
#  '쿨코튼2-PACK티셔츠',
#  '[패키지]NYCLOCATIONT-SHIRT(16Colors)[LRPMCTA401M]',
#  '020940레이어드반팔티',
#  '[세트상품]더블코튼롱티셔츠',
#  '베이식크루넥반팔티셔츠[블랙]',
#  '우먼즈베이식크루넥반팔티셔츠[화이트]',
#  '빅트위치로고티셔츠화이트',
#  'EMBROIDERYHANDSOMEDANTEEBLACK',
#  '고밀도순면기본반팔티셔츠_3팩MATS0101',
#  '릴렉스핏크루넥반팔티셔츠2팩',
#  'UNIVERSITYHANDSOMEDANTEEWHITE',
#  '(2PACK)1301무지반팔티블랙&화이트',
#  '미시간울버린피그먼트반팔티블랙차콜',
#  '(1+1세트구성)챔피온T425티셔츠',
#  '[패키지]에디오버핏반팔티셔츠패키지KJST2189',
#  'EMBROIDERYHANDSOMEDANTEENAVY',
#  '슈무아치로고반팔티셔츠화이트',
#  '더블엔젤와펜반팔티셔츠블랙',
#  'UNIVERSITYHANDSOMEDANTEENAVY',
#  'YOUNG프리미엄실켓티셔츠',
#  '10/20배송TAGRBTEE-BLACK',
#  '아치로고티셔츠화이트',
#  'EBFD에코코튼2-PACK베츠기본티셔츠블랙/화이트',
#  '어센틱로고티셔츠화이트',
#  '(TITLE)DJHANDSOMEDANTEEWHITE',
#  '우먼즈베이식크루넥반팔티셔츠[블랙]',
#  '[패키지]더블코튼무지반팔패키지KHST1011',
#  '(2PACK)T425무지반팔티(11color)',
#  '사인로고반팔티셔츠블랙',
#  'UNIVERSITYHANDSOMEDANTEEBLACK',
#  '[쿨탠다드]쿨탠다드릴렉스핏크루넥반팔티셔츠[블랙]',
#  '[패키지]Short_sleeve레이어드트임반팔티',
#  '사인로고반팔티셔츠화이트',
#  '1301무지반팔티',
#  '어센틱로고티셔츠블랙',
#  'PHYS.ED.DEPT®YOGABEGINNERCLASSLIGHTSSGRAY',
#  '[유아인착용상품]쿨탠다드릴렉스핏크루넥반팔티셔츠[화이트]',
#  '(3PACK)1301무지반팔티블랙&화이트',
#  '오버사이즈크루넥반팔티셔츠[화이트]',
#  '라인서퍼맨티셔츠화이트',
#  'EMBROIDERYHANDSOMEDANTEEIVORY',
#  'LOCATIONSHORTSLEEVEKS[BLACK]',
#  'EFF베츠반팔티셔츠블루',
#  '폰테릴렉스핏크루넥반팔티셔츠[화이트]',
#  '[UNISEX]45수특양면옆트임오버핏반팔티(화이트)',
#  '스몰사인로고반팔티셔츠블랙',
#  '드라이스우시반팔티BV6708-010',
#  '우먼즈크루넥크롭반팔티셔츠[화이트]',
#  '[패키지]아이스버그반팔STST3279+스플래쉬반팔STST3278',
#  'T425무지반팔티',
#  '헤리티지세리프로고루즈핏반팔티(FE2RSD5111XOWH)',
#  '스몰엔젤프린팅반팔블랙',
#  '더블엔젤와펜반팔티셔츠화이트',
#  '베이식크루넥반팔티셔츠2팩',
#  '릴렉스핏크루넥반팔티셔츠[다크그레이]',
#  'N202UTS910스토크오버핏반팔티셔츠BLACK2',
#  '레이어드크루넥반팔티셔츠_긴기장2팩',
#  '[세트상품]085-CVT17수무지반팔티',
#  'T-LogoTeeBlack(003)',
#  '7.0oz반팔티(화이트)',
#  '서핀백프린트티셔츠_네이비',
#  'RL001오리지널로고반팔티화이트',
#  '빅트위치로고티셔츠블랙',
#  'T-LogoTeeWhite(003)',
#  '스트라이프반팔티셔츠블랙',
#  '에센셜베이직티셔츠[OFFWHITE]',
#  '[패키지][CHUBBY]EMBROIDERYTEE(5COLOR)',
#  '스몰슈무반팔티셔츠블랙',
#  '빅트위치로고티셔츠레드',
#  '포켓반팔티17종/K87',
#  'LMCWATERSPLASHTEEwhite',
#  '빅트위치로고티셔츠네이비',
#  '[Mmlg]1987MMLGHF-T(BLACK)',
#  '세리프아치로고티셔츠화이트',
#  '라인서퍼맨티셔츠네이비',
#  '릴렉스핏크루넥반팔티셔츠[네이비]',
#  '쿨코튼2-PACK티셔츠화이트',
#  'C.r.e.a.mSEMIOVERFITT-SHIRT(WHITE)',
#  '(2PACK)T425무지반팔티블랙&화이트',
#  '유니섹스오버핏어스넷로고티-블랙',
#  '엔젤와펜반팔티셔츠화이트',
#  '스몰사인로고반팔티셔츠화이트',
#  'K87워크웨어포켓반팔티셔츠(20colors)',
#  '크루넥7부티셔츠[블랙]',
#  'EMBROIDERYHANDSOMEDANTEESTRIPE',
#  '2TONEARCHTEEWHITE',
#  '쿨탠다드릴렉스핏크루넥반팔티셔츠2팩',
#  '폰테릴렉스핏크루넥반팔티셔츠2팩',
#  'LOCATIONSHORTSLEEVEKS[WHITE]',
#  '릴렉스핏크루넥반팔티셔츠[그레이쉬블루]',
#  'C.r.e.a.mSEMIOVERFITT-SHIRT(BLACK)',
#  '243801코튼져지크루넥3pcs패키지',
#  '[Mmlg]MMLGHF-T(WHITE)',
#  'M-LogoClassic(GL5TSU173WH)',
#  '[세트상품]스탠다드코튼립티셔츠',
#  '[세트구성]1301무지반팔티',
#  '[Mmlg]1987MMLGHF-T(WHITE)',
#  '유니섹스오버핏어스넷로고티-화이트',
#  '헤비웨이트릴렉스드크루넥반팔티셔츠[화이트]',
#  '헤리티지세리프로고루즈핏반팔티(FE2RSD5111XBLK)',
#  '수피마릴렉스드크루넥반팔티셔츠2팩',
#  '순면라운드반팔오리지널3팩HATS0101',
#  'Y.E.SC-logoteeWhite',
#  '엔젤와펜반팔티셔츠블랙',
#  '오버사이즈크루넥반팔티셔츠2팩',
#  '로고&스마일리티셔츠_화이트(IK2BMMT517A)',
#  '유니섹스오버핏어스넷로고티-퍼플',
#  '[20수]기본무지세미오버반팔티-화이트-',
#  '스몰슈무반팔티셔츠화이트',
#  '우먼즈베이식크루넥반팔티셔츠[크림]',
#  'LOCATIONSHORTSLEEVEKS[INDIGOBLUE]',
#  '유니섹스365반팔티세트',
#  '레이어드크루넥반팔티셔츠_긴기장[블랙]',
#  '에센셜베이직티셔츠[BLACK]',
#  '우먼즈릴렉스핏크루넥반팔티셔츠[화이트]',
#  '빅트위치로고티셔츠아이보리',
#  'UNIVERSITYHANDSOMEDANTEEWHITE/ORANGE',
#  '카멜파크반팔티셔츠(딥그린)',
#  '베이식크루넥반팔티셔츠[오트밀]',
#  '[세트]반팔티+반바지',
#  'ARCLogoTeeBlack',
#  '[패키지]더블코튼무지반팔4PACKKHST1011',
#  '[Mmlg]MMLGHF-T(MELANGEBLUE)',
#  '7.0oz반팔티',
#  '[WT]TMR-TH001[반팔레이어드티셔츠]',
#  '폰테릴렉스핏크루넥반팔티셔츠[블랙]',
#  'Short_sleeve레이어드트임반팔티',
#  'T-LogoTeeWhite(002)',
#  'Y.E.SC-logoteeBlack',
#  '쿠퍼로고티셔츠네이비',
#  '페이퍼웨일티셔츠화이트',
#  '[프리미엄]실켓릴렉스핏크루넥반팔티셔츠[화이트]',
#  '유니섹스365반팔티화이트',
#  '[최겨울PICK]백로고3팩반팔티셔츠BACKLOGO3PACKTS',
#  '(LOUD)Boysbeloud티셔츠(포토카드)_SPRLB49C31',
#  '[Mmlg]MMLGHF-T(BLACK)',
#  'MARITHEWREGULARMARITHETEEwhite',
#  '마우이x레디파인애플쿠키반팔티[크림]',
#  '릴렉스핏크루넥포켓반팔티셔츠[블랙]',
#  '무지모달머슬핏반팔티(블랙)',
#  '릴렉스핏크루넥반팔티셔츠[크림]',
#  'FOUROTTERSTEE',
#  '피그먼트스몰어센틱로고티셔츠차콜',
#  '[패키지]오버핏그래픽반팔티셔츠3PACK_BB2H18881',
#  '반스클래식티셔츠-블랙/VN000GGGY281',
#  'EFF베츠반팔티셔츠블랙',
#  '오버핏엔젤레이어드티셔츠화이트',
#  '[패키지]핀스오버핏카라반팔티2PACKYHST2354',
#  '[후아유X깡스타일리스트]라벨반팔티WHRAB3796U',
#  'RETRIEVERSHORTSLEEVEKS[NAVY]',
#  '오버사이즈크루넥반팔티셔츠[블랙]',
#  '사인로고반팔티셔츠다크그레이',
#  'OTTERLOGOTEE4PACKSET',
#  '마우이x레디파인애플쿠키반팔티[차콜]',
#  '마우이x레디인터내셔널반팔티[차콜]',
#  '롱레이어드트임반팔티',
#  '빅트위치로고티셔츠퍼플',
#  '슈무티셔츠-블랙/GD3508',
#  'FLOWERMARDITEEWHITE-GREEN',
#  '[SET]프리미엄싱글세미오버핏티셔츠(10color)',
#  '포켓티화이트/K87-WHT',
#  '[원단선택가능]메쉬쿨론코코넛트리반팔티오프화이트',
#  'MARITHEWEMBROIDERYTEEwhite',
#  '워크웨어포켓반팔티K8715종',
#  '릴렉스핏크루넥반팔티셔츠[스모크핑크]',
#  '(2PACK)2000USA핏무지반팔티',
#  '릴렉스핏크루넥포켓반팔티셔츠[화이트]',
#  '빅트위치로고티셔츠그린',
#  '크루넥7부티셔츠[화이트]',
#  '컬러그라데이션오버핏반팔티셔츠BLACK',
#  '스몰사인로고반팔티셔츠네이비',
#  'FORESTWARS반팔티셔츠Black',
#  'AppleT-shirt(IVORYWHITE)',
#  '어센틱머슬핏반팔티8color',
#  'RL001오리지널로고반팔티블랙',
#  '(2PACK)1301무지반팔티',
#  '서핑엔젤반팔티셔츠화이트',
#  'OversizeWaterWashedT-Shirts[Charcoal]',
#  '[3패키지]컴포터블반팔라운드넥티셔츠_화이트',
#  '슈무아치로고반팔티셔츠블랙',
#  '085-CVT17수무지반팔티화이트',
#  '릴렉스핏크루넥반팔티셔츠[머스터드]',
#  '[세트상품]에센셜레이어드슬리브반팔티셔츠',
#  '사인로고반팔티셔츠네이비',
#  '엔젤로고반팔티셔츠블랙',
#  'V.O.CTEE(OLYMPIA)_WHITE',
#  '캠퍼스숫자반팔티셔츠_SPRPB25C24',
#  '15sinvisibletee-black-',
#  '릴렉스핏크루넥반팔티셔츠[라이트그레이]',
#  '릴렉스핏크루넥반팔티셔츠[베이지]',
#  'KittenBoxyTee[BLACK]',
#  'TRIPLEBEARST-SHIRT(3color)',
#  '빅트위치로고티셔츠버건디',
#  '무지모달머슬핏반팔티(화이트)',
#  'TAGRBTEE-WHITE',
#  '[패키지]롱레이어드트임반팔티',
#  '[3SET]3PACK1301무지반팔티',
#  '엔젤로고반팔티셔츠화이트',
#  'LMCWATERSPLASHTEEblack',
#  '오버사이즈쿨링베이스티셔츠-블랙-',
#  '로고&스마일리티셔츠_라이트블루(IK2BMMT517A)',
#  'MTEC티셔츠-블랙/FM5402',
#  '릴렉스핏크루넥반팔티셔츠[블루]',
#  '[후아유X깡스타일리스트]라벨반팔티셋업',
#  '[16수]레터링타투오버핏티셔츠블랙',
#  'C.r.e.a.mSEMIOVERFITT-SHIRT(BLUEGRAY)',
#  '릴렉스드반팔티셔츠[화이트]',
#  '피그먼트스몰어센틱로고티셔츠크림',
#  '레터링로고반팔티셔츠-마린블루-',
#  'INLOVETEE(WHITE)',
#  'BOXLOGOSHORTSLEEVEKS[BLACK]',
#  '에센셜웜코튼2-PACK티셔츠',
#  '서핑엔젤반팔티셔츠블랙',
#  'EFF베츠반팔티셔츠화이트',
#  '[원단선택가능]트레일러반팔티(black)',
#  '릴렉스핏크루넥반팔티셔츠[라이트카키]',
#  '락업티-블랙/ED6116',
#  '크루넥7부티셔츠[다크베이지]',
#  '오버사이즈쿨링베이스티셔츠-아이보리-',
#  '네츄럴U-넥하프티_화이트',
#  '로고&스마일리티셔츠_블랙(IK2BMMT517A)',
#  'UNIVERSITYHANDSOMEDANTEEOATMEAL',
#  '포켓티네이비/K87-NVY',
#  '[16수]헤비오버핏블록로고반팔',
#  '1301무지티반팔티',
#  '(LOUD)유닛티셔츠(포토카드)_SPRLB49C32',
#  '7.5oz맥스헤비웨이트무지오버핏반팔티_화이트',
#  '반팔로고티블랙/K195-001',
#  '[세트상품][패키지]미니멀더블코튼반팔티',
#  '컴포트레이어드티셔츠_White',
#  '액티비티클럽피그먼트반팔티크림',
#  '[패키지][UNISEX]45수특양면옆트임오버핏반팔티(화이트/블랙)',
#  'INFLUENCERDOODLETEEWHITE(MG2BMMT503D)',
#  '헤리티지세리프로고루즈핏반팔티(FE2RSD5111XGBL)',
#  '드로잉레이아웃로고티셔츠차콜',
#  'RETRIEVERSHORTSLEEVEKS[MELANGEGREY]',
#  '우먼즈베이식크루넥반팔티셔츠[라이트그레이]',
#  '장미자수반팔_블랙',
#  '릴렉스핏크루넥반팔티셔츠[브라운]',
#  '[20수]헤비오버핏보더반팔티블랙',
#  '플라워스탠드티셔츠블랙',
#  '수피마릴렉스드크루넥반팔티셔츠[블랙]',
#  '[COOLTECH]쿨링코튼오버핏티셔츠_SPLOB25U19',
#  'FlockingSymbolLogoTeeWhiteMelange',
#  'MATINKIMLOGOSILKETCROPTOP',
#  'RAINBOWREFLECTIVELOGOTEEBLACK(MG2BSMT504A)',
#  'S**tBearTeeBlack',
#  '릴렉스핏크루넥반팔티셔츠[라임]',
#  'M-LogoClassic(GL5TSU173BK)',
#  '7.0oz반팔티(블랙)',
#  '오버핏엔젤레이어드티셔츠블랙',
#  '우먼즈크루넥크롭반팔티셔츠[블랙]',
#  'M-LogoClassic(GL5TSU173IV)',
#  'LMCFLOWERGARDENTEEwhite',
#  '10/12배송ORIGINALLOGO2PACKT-SHIRTS_multi',
#  '[Mmlg]1987HF-T(WHITE)',
#  'NYCLOCATIONT-SHIRT(BLACK)[LRPMCTA401MBKA]',
#  '반스XIT티-(테러)IT',
#  'WILD수피마티셔츠',
#  '스탠다드스몰로고티셔츠STANDARDSMALLLOGOTS',
#  '웨이크보드반팔티셔츠(블랙)',
#  '플라워스탠드티셔츠화이트',
#  '코튼프리미엄티셔츠_화이트',
#  '베이식크루넥반팔티셔츠[네이비]',
#  'OverdyedMarsTeeCharcoal',
#  '[쿨탠다드]쿨탠다드릴렉스핏크루넥반팔티셔츠[다크그레이]',
#  'MARITHEWCLASSICLOGOTEEoffwhite',
#  '토리와호수니반팔티셔츠[다크그레이]',
#  '[SET]퓨어헤비반팔티셔츠(8color)',
#  'UNIVERSITYHANDSOMEDANTEECREAM',
#  '씨코스트마운틴피그먼트오버핏반팔티블랙차콜',
#  'OfficeJunior1/2T-shirt(Ivory)',
#  '베이식크루넥반팔티셔츠[멜란지그레이]',
#  '[쿨탠다드]쿨탠다드릴렉스핏크루넥반팔티셔츠[네이비]',
#  '릴렉스핏크루넥반팔티셔츠[오렌지]',
#  '캡슐백로고반팔티셔츠CAPSULEBACKLOGOTS',
#  'RL701비더프렌즈반팔-화이트',
#  'DEFAULTARCHLOGOTEE2PACKSET',
#  'black_replaycampaignstee(green)',
#  '3TAGLESST-ShirtsWhite',
#  '[쿨탠다드]쿨탠다드릴렉스핏크루넥반팔티셔츠[크림]',
#  '레이어드크루넥반팔티셔츠_긴기장[더스티카키]',
#  '레이어드크루넥반팔티셔츠_긴기장[오트밀]',
#  '레이어드크루넥반팔티셔츠_긴기장[코코아]',
#  '레이어드크루넥반팔티셔츠_긴기장[더스티베이지]',
#  '레이어드크루넥반팔티셔츠_긴기장[미드나잇블루]',
#  '레이어드크루넥반팔티셔츠_긴기장[그레이]',
#  '레이어드크루넥반팔티셔츠_일반기장[라이트그레이]',
#  '레이어드크루넥반팔티셔츠_일반기장[블랙]',
#  '레이어드크루넥반팔티셔츠_일반기장[머쉬룸]',
#  '레이어드크루넥반팔티셔츠_일반기장[미디엄그레이]',
#  '레이어드크루넥반팔티셔츠_일반기장[다크그레이]',
#  '레이어드크루넥반팔티셔츠_일반기장[화이트]',
#  '레이어드크루넥반팔티셔츠_일반기장[크림]',
#  'BASICLOGOTEEWHITE(MG2BSMT502A)',
#  '레이어드크루넥반팔티셔츠_일반기장2팩',
#  '(2PACK)76000아시안핏무지반팔티',
#  '[세트]오버핏마리화나로고티',
#  '캠프바시티피그먼트오버핏반팔티블랙차콜',
#  'Y.E.SFlowerTeeWhite',
#  '릴렉스핏크루넥반팔티셔츠[버건디]',
#  '(우디)여성그래픽반팔티셔츠_SPRPB37G93',
#  '마우이x레디인터내셔널반팔티[크림]',
#  '레이어드숏슬리브티셔츠화이트',
#  '마우이x레디인터내셔널반팔티[블루]',
#  '(잔망루피)루피군싹티셔츠_SPRLB37C03',
#  'LogoT-shirts(GK2TSU091WH)',
#  '베이식크루넥반팔티셔츠[크림]',
#  '[16수]문캐처아트웍반팔블랙',
#  'BWindowT-shirt(Cream)',
#  '스타일숏슬리브라운드티셔츠멜란지그레이',
#  'modernartT-shirts',
#  'dailychaecklistT-shirts',
#  'breakfastT-shirts',
#  'BurningT-shirts',
#  '꽈당T-shirts',
#  'blackboardT-shirts',
#  'HowtomakeasockpuppetT-shirts',
#  'PHYS.ED.DEPT®YOGABEGINNERCLASSSSWHITE',
#  '10/12배송2020SIGNATURET-SHIRTS_white',
#  'EMBROIDERYHANDSOMEDANLAYEREDVESTNAVY',
#  '1970로고티셔츠화이트',
#  '썸머엔젤반팔티셔츠블랙',
#  '네츄럴U-넥하프티_블랙',
#  '유니섹스365반팔티블랙',
#  'M-LogoClassic(GL5TSU173NA)',
#  '(AR5004)NSW퓨추라반팔티2컬러',
#  '스타일고데어숏슬리브티셔츠BEIGE',
#  '스타일고데어숏슬리브티셔츠BLACK',
#  'NYCLOCATIONT-SHIRT(WHITE)[LRPMCTA401MWHA]',
#  '썸머엔젤반팔티셔츠화이트',
#  'IVYLAYEREDVESTNAVY',
#  '팀레전드SS크루드라이핏반팔티셔츠블랙(NI-TT4)',
#  '슈무티셔츠-베이지/GD3509',
#  'C.r.e.a.mSEMIOVERFITT-SHIRT(DUSTYMINT)',
#  '베이직하프티_블랙',
#  '팀레전드SS크루드라이핏반팔티셔츠화이트(NI-TT4)',
#  '릴렉스핏크루넥반팔티셔츠[멜란지그레이]',
#  'ODSD빅로고컬러웨이티셔츠-8COLOR',
#  '[UNISEX]45수특양면옆트임오버핏반팔티(블랙)',
#  '팀레전드SS크루드라이핏반팔티셔츠네이비(NI-TT4)',
#  '2PACKTEE(MG2BSMT540A)',
#  '3-스트라이프티셔츠-블랙/CW1202',
#  '우먼스드라이핏스우시반팔티셔츠블랙(NI-WT2)',
#  '쉐도우티셔츠-화이트/FU6002',
#  '크루넥7부티셔츠[다크그레이]',
#  '릴렉스핏크루넥반팔티셔츠[더스티크림]',
#  'Y06794스크립트로고반팔티화이트',
#  '돈워리반팔티셔츠[2COL]/S21W05018',
#  '아임던반팔티셔츠[2COL]/S21W05015',
#  '10/12배송2021SIGNATURET-SHIRTS[CREAM]',
#  '우먼스드라이핏스우시반팔티셔츠화이트(NI-WT2)',
#  '코튼프리미엄티셔츠_블랙',
#  '우먼즈릴렉스핏크루넥반팔티셔츠[블랙]',
#  '10/8배송솔리드옥스포드오버셔츠(스카이블루)',
#  '10/12배송솔리드옥스포드오버셔츠(화이트)',
#  '릴렉스핏옥스포드셔츠[화이트]',
#  '플러프무드체크셔츠S24네이비',
#  'STRIPEHANDSOMEDANSHIRTBLUE',
#  'WooltanCheckShirts(Cream)',
#  '10/14배송시티보이빅오버워싱데님셔츠_Black',
#  '스티브보이핏오버셔츠WHYAB4991U',
#  '베이식옥스포드셔츠[화이트]',
#  '베이식드레스셔츠[화이트]',
#  '오버핏옥스퍼드셔츠(BLUE)',
#  '빈티지블랙도트스트라이프셔츠S22',
#  '10/15배송솔리드옥스포드오버셔츠(블랙)',
#  '루즈핏오픈카라텐셀린넨셔츠[네이비]',
#  '클래식화이트셔츠S40',
#  '10/6배송시티보이빅오버워싱데님셔츠_LightBlue',
#  '10/13배송SH9304프렌치스트라이프셔츠',
#  '10/19배송[빅오버핏]폴리셔츠S37-2애쉬그레이',
#  '릴렉스핏옥스포드셔츠[블루]',
#  '엔젤와펜셔츠멀티스트라이프',
#  '10/13배송시티보이빅오버옥스포드셔츠_OffWhite',
#  '릴렉스핏실키셔츠[블랙]',
#  '10/8배송시티보이빅오버옥스포드셔츠_NeutralGray',
#  '시티보이빅오버워싱데님셔츠_MiddleBlue',
#  '시티보이빅오버옥스포드반팔셔츠_SkyBlue',
#  '릴렉스핏옥스포드셔츠[그레이]',
#  '10/13배송솔리드옥스포드오버셔츠(바이올렛)',
#  '10/15배송헤링본클래식체크셔츠S41',
#  'HairLineStripeShirtsSky',
#  '10/15배송폴링체크셔츠S43',
#  '오버사이즈히든미니멀셔츠[WHITE]',
#  '루즈핏오픈카라텐셀린넨셔츠[블랙]',
#  '오버핏옥스퍼드셔츠(WHITE)',
#  '릴렉스핏실키셔츠[그레이쉬블루]',
#  '플러프무드체크셔츠S24브라운',
#  '10/8배송시티보이빅오버옥스포드셔츠_SkyBlue',
#  '10/20배송솔리드옥스포드오버셔츠(자수버전/스카이블루)',
#  '10/6배송시티보이빅오버옥스포드스트라이프셔츠_BrownStripe',
#  '[홀리데이세일]UNISEXFLEXCHECKSHIRTBLUE',
#  '유니섹스포인트오버핏체크셔츠네이비',
#  '[패키지]매치오버핏셔츠4종BJLS4410',
#  '루즈핏오픈카라텐셀린넨셔츠[오트밀]',
#  '[타이SET]클래식코튼프렌치셔츠_MintGray',
#  '유니섹스옵티멀베이직린넨셔츠-화이트',
#  '세미오버핏타탄체크셔츠[엄버블랙]',
#  '[홀리데이세일][폴리]오버핏데일리체크셔츠_블랙',
#  '[유아인착용상품]릴렉스핏실키셔츠[카키]',
#  '10/15배송시티보이빅오버글렌체크셔츠_GlenCheck',
#  '10/12배송UNISEXFLEXCHECKSHIRTBLACK',
#  '오버핏울체크셔츠그레이',
#  '릴렉스핏실키셔츠[화이트]',
#  '10/20배송솔리드옥스포드오버셔츠(자수버전/블랙)',
#  '엔젤와펜셔츠스트라이프',
#  'SPRINGOVERSIZEDSHIRTBLUE',
#  '10/8배송시티보이빅오버옥스포드셔츠_RoyalBlue',
#  '릴렉스핏실키셔츠[다크네이비]',
#  '10/12배송스트라이프옥스포드오버셔츠(스카이블루)',
#  '시티보이빅오버셔츠_SkyBlueStripe',
#  '10/5배송sh1101옥스포드셔츠-화이트',
#  '유니섹스오버핏글림스트라이프셔츠-네이비',
#  '솔리드옥스포드오버셔츠(자수버전/화이트)',
#  '릴렉스핏옥스포드셔츠[블랙]',
#  '베이식포플린셔츠[화이트]',
#  '시티보이빅오버옥스포드반팔셔츠_White',
#  '10/15배송시티보이보트자수옥스포드오버핏셔츠(WHITE)',
#  '베이식드레스셔츠[블랙]',
#  '유니섹스베이스오버핏체크셔츠-네이비',
#  '[남/여]Overfitvintagecheckshirt_green',
#  '베이식옥스포드셔츠[블루]',
#  '피그먼트루즈핏셔츠베이지SMLS4058',
#  '10/15배송시그니처클럽셔츠_화이트',
#  '유니섹스오버핏글림스트라이프셔츠-블랙',
#  '루즈핏오픈카라린넨셔츠[화이트]',
#  '[남/여]오버핏와플체크셔츠-베이지',
#  '(UNISEX)아트체크셔츠',
#  'OVERFITMINIMALCOLORSHIRT_SKYBLUE',
#  '피그먼트루즈핏셔츠진회색SMLS4058',
#  'OxfordOverShirtsBlue',
#  '릴렉스핏실키셔츠[라이트베이지]',
#  '릴렉스핏실키셔츠[다크그레이]',
#  '릴렉스핏워시드데님셔츠[라이트인디고]',
#  '[리뉴얼]스테디블레이즈체크셔츠-오렌지',
#  '젠틀오픈세미오버핏셔츠블랙',
#  '베이식옥스포드셔츠[그레이]',
#  '[타이SET]클래식코튼프렌치셔츠_LightBeige',
#  '[쿨탠다드]트리코트이지셔츠[화이트]',
#  '와이드스프레드칼라드레스셔츠[화이트]',
#  '오버핏옥스퍼드셔츠(BLACK)',
#  '10/12배송LAUNDRYSHIRT(SKYBLUE)',
#  '10/14배송DenimOverShirtsWashed',
#  'C로고옥스포드스트라이프셔츠라이트블루',
#  '릴렉스핏실키셔츠[핑크]',
#  '하운드투스체크반팔셔츠카키HSSS2207',
#  '[컬러추가]PINSTRIPEOVERSHIRT',
#  '베이식옥스포드셔츠[블랙]',
#  'TP95PINSTRIPESHIRTS(BLACK)',
#  '오버사이즈히든미니멀셔츠[L.GREY]',
#  '옥스포드베이직셔츠화이트',
#  '엘보우다이아몬드스티치S68네이비',
#  '릴렉스핏워시드데님셔츠[미디움인디고]',
#  '오버사이즈히든미니멀셔츠[D.GREY]',
#  '린넨히든미니멀셔츠[SKYBLUE]',
#  '(UNISEX)클래시체크셔츠',
#  '릴렉스핏옥스포드워크셔츠[화이트]',
#  '[빅오버핏]폴리셔츠S37-2스카이블루',
#  '릴렉스핏실키셔츠[라이트그레이]',
#  '유틸리티빅오버옥스포드셔츠_SkyBlueStripe',
#  '릴렉스핏옥스포드셔츠[네이비]',
#  '솔리드옥스포드오버셔츠(자수버전/바이올렛)',
#  '[리뉴얼]스테디레잇체크셔츠-베이지',
#  '[타이SET]클래식코튼프렌치셔츠_OffWhite',
#  '릴렉스핏실키셔츠[다크브라운]',
#  '[빅오버핏]폴리셔츠S37-2베이지',
#  '로프스트라이프셔츠S46스카이블루',
#  '시티보이빅오버옥스포드반팔셔츠_AshGray',
#  '웨인듀노멀데님셔츠_DL_E30',
#  '오버핏옥스퍼드셔츠(GREY)',
#  '오버사이즈히든미니멀셔츠[BLUEGREY]',
#  '시티보이보트자수옥스포드오버핏셔츠(SKYBLUE)',
#  '10/7배송sh1101옥스포드셔츠-그레이블루',
#  '오버사이즈글렌체크셔츠.',
#  '와이드커프스옷핀셔츠_화이트',
#  '10/22배송oxfordbdshirtsblue',
#  '10/4배송자이언트핏포켓데님셔츠(연청)',
#  '시티보이옥스포드원포켓오버핏솔리드셔츠화이트',
#  '오버핏프렌치셔츠_OffWhite',
#  '헤링본체크셔츠S47갤럭시네이비',
#  '히든버튼드레스셔츠[화이트]',
#  'SPRINGOVERSIZEDSHIRTGREEN',
#  '[타이SET]클래식코튼프렌치셔츠_DarkBrown',
#  '[린넨]오버핏스탠다드스티치셔츠S74그레이',
#  '릴렉스핏옥스포드셔츠[베이지]',
#  'RamieHalfShirts(Beige)',
#  'OxfordOverShirtsWhite',
#  '미니멀카라린넨풀오버셔츠[NAVY]',
#  '[슬로우보이X바나]21FWOVERSIZEDSTRIPESHIRKETBEIGE',
#  'OxfordOverShirtsGreyStripe',
#  '미니멀카라린넨풀오버셔츠[CHARCOAL]',
#  '스티치오버핏셔츠스카이블루',
#  '10/5배송sh0103페이퍼셔츠-화이트',
#  '이지케어오버셔츠라이트블루',
#  '[홀리데이세일][아노블리어X니티드]루즈핏얼터너티브스트라이프셔츠[네이비]',
#  '루즈핏오픈카라텐셀린넨셔츠[카키]',
#  '시티보이보트자수옥스포드오버핏셔츠(BLACKSTRIPE)',
#  '[아노블리어X키르시]스몰체리옥스포드셔츠[화이트]',
#  '릴렉스핏옥스포드셔츠[크림]',
#  '트위치로고오버핏옥스포드셔츠블루',
#  'LAUNDRYSHIRT(LEMON)',
#  '베이직옥스포드버튼다운셔츠_화이트',
#  'AvaCollagePrintedShirtWhite',
#  'OverfitCheckShirts_Black',
#  '[남/여]Overfitvintagecheckshirt_brown',
#  '오픈카라링클프리페이즐리반팔셔츠BLACK',
#  '피그먼트루즈핏셔츠검정SMLS4058',
#  '오버사이즈히든미니멀셔츠[CREAM]',
#  'BBHEAVYSHIRTS-GREY',
#  '컬러배색세일러카라데님블라우스',
#  '유니섹스웨이브핸드스티치오버셔츠_딥그린',
#  '유니섹스실스티치오버셔츠_아이보리',
#  '유니섹스실스티치오버셔츠_차콜그레이',
#  '유니섹스웨이브핸드스티치오버셔츠_블랙',
#  '유니섹스웨이브핸드스티치오버셔츠_아이보리',
#  '10/22배송YOWL클래식체크셔츠그린네이비',
#  'UNISEXMAN오피스차이나카라오버핏셔츠화이트',
#  'WOMAN오피스차이나카라오버핏셔츠화이트',
#  'AvaCollagePrintedShirtDenimBlue',
#  'CheckFullZipShirtBrown',
#  '[리뉴얼]스테디웨이브체크셔츠-브라운',
#  'CheckFullZipShirtDarkBlue',
#  '10/27배송[21FW]링클프리베이직셔츠_WHITE',
#  'SIMPLESHIRT_WHITE',
#  '홀리데이체크셔츠[PINK]/S21W04002',
#  'FW21Beltedpoplintopblack',
#  '홀리데이체크셔츠[BEIGE]/S21W04002',
#  '오버사이즈코튼셔츠그린',
#  'MOODCHECKSHIRT_PINK',
#  '빅카라타탄체크블라우스',
#  'Pointpuffcollarstripeblouse_navy',
#  'MOODCHECKSHIRT_MINT',
#  '오버사이즈코튼셔츠옐로우',
#  'Pointpuffcollarstripeblouse_lightbeige',
#  'SIMPLESHIRT_KHAKI',
#  '오버사이즈타탄체크셔츠블랙FLS201',
#  'Whitelacehighneckpuffblouse',
#  '발마칸웰트포켓셔츠자켓블랙',
#  '발마칸웰트포켓셔츠자켓화이트',
#  '발마칸웰트포켓셔츠자켓그레이',
#  '트렌치웰트포켓셔츠자켓베이지',
#  '트렌치웰트포켓셔츠자켓블랙',
#  '[리뉴얼]스테디와이드체크셔츠-그린',
#  '오버핏라운드옥스포드셔츠_블랙',
#  '오버핏라운드옥스포드셔츠_화이트',
#  '멀티스트라이프셔츠_화이트',
#  '크롭울블라우스-베이지',
#  '크롭울블라우스-블랙',
#  '[SLIM]네이비울블렌드브러시드셔츠(BC1964A30R)',
#  '10/15배송HALFTONEJERSEYSHIRT(BLACK)',
#  '[SLIM]와인울블렌드브러시드셔츠(BC1964A30Z)',
#  '[SLIM]카키울블렌드브러시드셔츠(BC1964A30H)',
#  '워시드옥스포드셔츠_화이트',
#  'HEAVY8WCORDUROYSHIRTJACKET_OLIVE',
#  'CORDUROYBELTSHIRT/BLACK',
#  '뮤트톤옥스퍼드시티보이셔츠파스텔블루',
#  '10/13배송유니섹스데이즈오버핏체크셔츠-블랙',
#  '솔리드옥스포드히든셔츠S67스카이블루',
#  '10/15배송HALFTONEJERSEYSHIRT(WHITE)',
#  '멀티스트라이프셔츠_네이비',
#  '도비유틸리티오버셔츠-그린',
#  '매치오버핏셔츠흰색BJLS4410',
#  '노블체크셔츠자켓_화이트',
#  '뮤트톤옥스퍼드시티보이셔츠브라운',
#  '뮤트톤옥스퍼드시티보이셔츠민트',
#  '[홀리데이세일]로얄블루오버핏울체크셔츠',
#  'WOMEN크롭슬림반팔셔츠[WHITE]크롭티반팔티',
#  '113EASYCARELINENSHIRTS[LIGHTBEIGE]',
#  '오버사이즈플란넬체크셔츠네이비FLS202',
#  '오버사이즈플란넬체크셔츠브라운FLS202',
#  '뮤트톤옥스퍼드시티보이셔츠네이비',
#  'RC클럽옥스포드셔츠_화이트',
#  '뮤트톤옥스퍼드시티보이셔츠블랙',
#  '엔젤옥스포드긴팔셔츠화이트',
#  '오버핏체크셔츠G070',
#  '베이직포켓데님셔츠LI10BL102',
#  '오버핏체크셔츠B070',
#  '클로이윙클카라블라우스',
#  '빅카라레더셔츠-브라운',
#  '커프스롱셔츠-아이보리',
#  '커프스롱셔츠-블랙',
#  '빅카라레더셔츠-블랙',
#  '10/11배송EMBROIDERYHANDSOMEDANSHIRTSTRIPEVIOLET',
#  '버터레더셔츠[BLACK]/S21W04003',
#  '오버핏체크셔츠W070',
#  '미니멀카라린넨풀오버셔츠[BLACK]',
#  '뮤트톤옥스퍼드시티보이셔츠라벤더',
#  '뮤트톤옥스퍼드시티보이셔츠화이트',
#  '베이식옥스포드셔츠[베이지]',
#  '이지케어오버셔츠세트',
#  '베이식옥스포드셔츠[크림]',
#  'ArtworkPrintCheckShirtsBlue',
#  '페더웨이트메시셔츠-화이트',
#  '10/15배송BIGDENIMSHIRTINDIGO',
#  '10/15배송BIGDENIMSHIRTLIGHTBLUE',
#  'BANDINGCROPPEDSHIRT_Navy',
#  'SOFTSHIRT_Cottonpaleblue',
#  'BANDINGCROPPEDSHIRT_Charcoalbrown',
#  'BANDINGCROPPEDSHIRT_White',
#  'SOFTSHIRT_Cottonwhite',
#  'SOFTSHIRT_Silkypink',
#  '베이식드레스셔츠[스카이블루]',
#  '10/5배송sh0103페이퍼셔츠-민트그레이',
#  '테이크데일리스탠다드셔츠',
#  '오버핏롱셔츠화이트',
#  '도비유틸리티오버셔츠-카키',
#  'RC클럽옥스포드셔츠_스카이블루',
#  '오버핏클라우디체크셔츠S72네이비',
#  '플란넬솔리드셔츠[뉴스탠다드]_M216MSH752M',
#  '플란넬솔리드셔츠[뉴스탠다드]_M216MSH751M',
#  '시티보이베이직옥스퍼드셔츠-스카이블루',
#  '코듀로이오버사이즈셔츠재킷[더스티베이지]',
#  '슬림핏멜란지체크셔츠(T12B7WSH410MT20N1)',
#  '오버사이즈히든미니멀셔츠[BLACK]',
#  '시티스트라이프오버셔츠(시티블랙)',
#  '슬림핏멜란지체크셔츠(T12B7WSH410MT20QJ)',
#  '캐시미어투스셔츠(T12B9WSH160MT20OG)',
#  '캐시미어투스셔츠(T12B9WSH160MT20MS)',
#  '슬림핏멜란지체크셔츠(T12B7WSH410MT20OV)',
#  '프레첼코듀로이셔츠딥베이지JJLS7525',
#  '프레첼코듀로이셔츠베이지JJLS7525',
#  '유니섹스옵티멀베이직린넨셔츠-네이비',
#  '릴렉스핏코듀로이셔츠[화이트]',
#  'Logostripeshirt',
#  '프레첼코듀로이셔츠크림JJLS7525',
#  '프레첼코듀로이셔츠카키JJLS7525',
#  'Winelogoshirt',
#  '113EASYCARELINENSHIRTS[SKYBLUE]',
#  '여성옵션끈장식블라우스-AERG5454B03',
#  '남성헤링본조직캐주얼셔츠-AERK5413B0C',
#  '남성모던윈도우체크셔츠-AERK5412B0G',
#  '프레첼코듀로이셔츠네이비JJLS7525',
#  '여성사이드오픈코튼셔츠-AEAG5455B0D',
#  'ArtworkPrintCheckShirtsOrange',
#  '남성세미오버핏겉기모체크셔츠-AFRK5416C08',
#  '아이보리코튼트윌아우터형셔츠_릴랙스핏(261964EY10)',
#  '옐로우플란넨옴브레체크긴팔셔츠_릴랙스핏(261964EY2E)',
#  '베이지에코스웨이드오버셔츠_레귤러핏(26193ZEY1A)',
#  '[패키지]스탠다드오버핏옥스포드셔츠+스탠다드오버핏옥스포드셔츠',
#  '남성세미오버핏겉기모체크셔츠-AFRK5416C03',
#  '블랙글로시블라우스',
#  '남성세미오버핏모던솔리드셔츠-AERK5411B0M',
#  '남성세미오버핏모던솔리드셔츠-AERK5411B03',
#  '에브리데이오버핏셔츠[차콜]',
#  'oxfordbdshirtsgrey',
#  '[패키지]더오버핏셔츠2PACKJJLS7513',
#  '여성옵션끈장식블라우스-AERG5454B0P',
#  '여성사이드오픈코튼셔츠-AEAG5455B0A',
#  '프레첼코듀로이셔츠블랙JJLS7525',
#  '041901브러쉬드링클프리이지케어셔츠(10041901)',
#  '리뉴얼그린체크셔츠S77',
#  'OVERLAPWORKSHIRT_WHITE',
#  'SUEDEOVERSIZEDCPOSHIRT_BLACK',
#  '프레첼코듀로이셔츠카키브라운JJLS7525',
#  '릴렉스핏워시드데님셔츠[블랙]',
#  '그란지솔리드오버셔츠[블랙]',
#  '그란지솔리드오버셔츠[라이트베이지]',
#  '그란지솔리드오버셔츠[샌드베이지]',
#  '그란지솔리드오버셔츠[올리브카키]',
#  '그란지솔리드오버셔츠[딥차콜]',
#  '[패키지]UNISEXFLEXCHECKSHIRT',
#  'CXLSummerShirt(Black)',
#  '10/8배송오버핏레터링옥스포드셔츠[화이트]',
#  '코듀로이오버사이즈셔츠재킷[블랙]',
#  'Y.E.SB-DRegularShirtLightBlue',
#  'CrossribbonsidebuttonBlouse-Beige',
#  'Pearlbuttonpuffyblouse-lightkhaki',
#  'Pearlbuttonpuffyblouse-White',
#  '[SLIM]네이비헤링본브러시드셔츠(BC1964A25R)',
#  '[SLIM]그레이헤링본브러시드셔츠(BC1964A253)',
#  '[SLIM]카키헤링본브러시드셔츠(BC1964A25H)',
#  '[SLIM]스카이블루헤링본브러시드셔츠(BC1964A25Q)',
#  'ShilingBlouse',
#  '오다카오버사이즈울자켓_ODAKAsSeparatedHoodieWoolJaket',
#  'CrossribbonsidebuttonBlouse-White',
#  '코듀로이벨벳셔츠2컬러',
#  'EV플레임로고셔츠',
#  'RegularCollarChaosSymbolOversizedShirt(2COLORS)',
#  '루즈핏셔링타이블라우스LI10BL100',
#  'pnv027나일론셔츠자켓(화이트)',
#  'pnv026나일론셔츠자켓(다크그레이)',
#  'pnv025나일론셔츠자켓(마린블루)',
#  '오버사이즈린넨풀오버카라셔츠[MINTGREY]',
#  'oxfordbdshirtsbrown',
#  'cottonshirts-middleblue',
#  '10/6배송빅오버기모체크셔츠_NavyCheck',
#  '[여름원단]시티보이빅오버린넨반팔셔츠_MidnightBlue',
#  '10/11배송EMBROIDERYHANDSOMEDANSHIRTLIGHTOLIVE',
#  '오버사이즈코튼셔츠[크림]',
#  '릴렉스드쇼트슬리브셔츠[블랙]',
#  '10/6배송빅오버기모체크셔츠_GrayCheck',
#  'CarterWorkShirtsOffWhite',
#  'HEAVY8WCORDUROYSHIRTJACKET_NAVY',
#  'CarterWorkShirtsSkyBlue',
#  '엘보우다이아몬드스티치S68베이지',
#  'OxfordOverShirtsBeige',
#  '에스닉블라우스[BROWN]',
#  '에스닉블라우스[ROSEPINK]',
#  '베이식코듀로이셔츠[블랙]',
#  '코튼옥스포드심플셔츠_EPB3WC1977GR',
#  '10/21배송와펜스몰하우스로고옥스포드셔츠화이트',
#  '릴렉스핏실키셔츠[더스티베이지]',
#  '와펜스몰하우스로고옥스포드셔츠블루',
#  '스탠드카라린넨셔츠[GREEN]',
#  '엔젤와펜셔츠블랙',
#  '베이식코듀로이셔츠[화이트]',
#  '루즈핏오픈카라텐셀린넨셔츠[모카베이지]',
#  '솔리드옥스포드히든셔츠S67오프화이트',
#  '밀라노오버핏체크셔츠-네이비',
#  '스트라이프믹스셔츠[뉴스탠다드]_M216MSH507M',
#  '와이드플래킷셔츠-StripeBlue',
#  '스탠드카라린넨셔츠[NAVY]',
#  '와이드플래킷셔츠-Navy',
#  '10/13배송스트라이프오버럭비티셔츠_GreenCream',
#  '10/6배송원버튼더블피케티_블랙',
#  '10/6배송스트라이프오버럭비티셔츠_NavyCream',
#  '슬릿넥피케폴로셔츠[블랙]',
#  'OAMFACTORYXOSLOGORUGBYTEE_BLACK',
#  '10/8배송헤비코튼오버럭비티셔츠_MidnightBlue',
#  '21S/S오버핏피케티셔츠(브라운)',
#  '롱슬리브피케폴로셔츠[블랙]',
#  '오픈카라티셔츠[BLACK]',
#  '쿨소프트숏슬리브카라니트오트밀',
#  '오버사이즈피케스웨트셔츠블랙',
#  '10/6배송스트라이프오버럭비티셔츠_GreenNavy',
#  '헤비코튼오버럭비티셔츠_Black',
#  '21S/S오버핏피케티셔츠(카키)',
#  '오픈카라티셔츠[INDIBLUE]',
#  '10/15배송스트라이프오버럭비티셔츠_YellowNavy',
#  '릴렉스핏피케폴로셔츠[블랙]',
#  '오픈카라티셔츠[TURQUOISEBLUE]',
#  '롱슬리브피케폴로셔츠[머쉬룸]',
#  '오픈칼라폴로셔츠[블랙]',
#  '베이식피케폴로셔츠[블랙]',
#  '[쿨탠다드]쿨탠다드피케폴로셔츠[블랙]',
#  '엔젤카라롱슬리브블랙',
#  '오픈카라티셔츠[BEIGE]',
#  '스탠다드카라PK티셔츠블랙',
#  '아쿠아스판PK티셔츠블랙',
#  '스탠다드카라PK티셔츠화이트',
#  '아쿠아스판PK티셔츠화이트',
#  '사이드레터링PK티셔츠블랙',
#  '사이드레터링PK티셔츠화이트',
#  '스탠다드PK티셔츠블랙',
#  '스탠다드PK티셔츠화이트',
#  '메쉬해골로고PK티셔츠화이트',
#  '메쉬해골로고PK티셔츠블랙',
#  '스탠다드썸머니트티셔츠화이트',
#  '스탠다드썸머니트티셔츠블랙',
#  '스탠다드썸머니트티셔츠화이트',
#  '에센셜오버피케스웨트셔츠[2COLOR]',
#  '[UNISEX]레인보우플라워도트자수화이트클립피케이카라롱슬리브_블랙',
#  '쿨소프트숏슬리브카라니트빈티지브라운',
#  '10/6배송헤비코튼오버럭비티셔츠_MelangeGray',
#  'CollarColorPointT-Shirts_Black',
#  'comfortablewhakipktshirts',
#  'PuffSleeveT-Shirts_White',
#  'FrillCollarBaseLayer_Navy',
#  'FrillCollarBaseLayer_Black',
#  'FrillCollarBaseLayer_White',
#  'comfortablearowtshirt',
#  'CollarColorPointT-Shirts_White',
#  '헤비코튼오버럭비티셔츠_SandBeige',
#  'BOLDSTRIPERUGBYTEE_IVORY/NAVY',
#  'OGPIGMENTDYEINGRUGBYTEE_CHARCOAL',
#  '[UNISEX]플라워도트자수화이트클립피케이카라롱슬리브_블랙',
#  '클래식핏아이코닉럭비셔츠-그린',
#  '여성아이보리스퀘어기모칼라티셔츠(BJ1941A720)',
#  '여성아이보리골지믹스칼라티셔츠(BJ1941A100)',
#  '럭비스트라이프티셔츠네이비',
#  'OGPIGMENTDYEINGRUGBYTEE_BLUE',
#  'BUTTERCREAMKNITHALFSHIRTS',
#  'BOLDSTRIPERUGBYTEE_OLIVE/NAVY',
#  'LapelTypeCollarPointT-Shirts_Navy',
#  '10/6배송빅오버사카리바코튼카라티셔츠_MidnightBlue',
#  'LapelTypeCollarPointT-Shirts_Lightgrey',
#  'EMB오픈카라스트라이프니트_라이트베이지',
#  '베이식피케폴로셔츠[머쉬룸]',
#  '시그니쳐티에리티셔츠_ZPB4TT1901BE',
#  '시그니쳐티에리티셔츠_ZPB4TT1901LGR',
#  '시그니쳐티에리티셔츠_ZPB4TT1901MT',
#  '시그니쳐티에리티셔츠_ZPB4TT1901NV',
#  '시그니쳐티에리티셔츠_ZPB4TT1901PK',
#  '10/6배송빅오버사카리바코튼카라티셔츠_SaddleBrown',
#  '10/6배송빅오버사카리바코튼카라티셔츠_MelangeGray',
#  '수피마코튼니티드롱슬리브폴로셔츠[블랙]',
#  '남성네이비레터링프린팅칼라티셔츠(BJ1941B07R)',
#  'pnv028원라인오버럭비티셔츠(네이비)',
#  'pnv029원라인오버럭비티셔츠(올리브카키)',
#  '엔젤카라롱슬리브스트라이프',
#  'PuffSleeveT-Shirts_Green',
#  'PuffSleeveT-Shirts_Navy',
#  '오픈카라티셔츠[INDIPINK]',
#  '10/18배송머튜얼반집업카라니트_Black',
#  'BOLDSTRIPERUGBYTEE_MUSTARD/NAVY',
#  '스트라이프카라니트_차콜민트',
#  '스트라이프카라니트_블랙차콜',
#  'K570포켓반팔카라폴로티(7컬러)',
#  '남성베이지투톤멜란지칼라티셔츠(BJ1841B16A)',
#  '원버튼피케티_블랙',
#  '팀클럽카라티블랙',
#  '플레인폴로셔츠[블랙]',
#  '롱슬리브피케폴로셔츠[다크그레이]',
#  '오픈카라루즈니트_라이트베이지',
#  '프리미엄폴로반팔T_SPHWB24M08',
#  '10/12배송폴로셔츠니트[블랙]',
#  '피케맨투맨블랙',
#  '011501오버핏긴팔폴로',
#  'CollarRibPulloverIVORY(JYSW1D910IV)',
#  '헤비코튼오버럭비티셔츠_SanddleBrown',
#  '클래식핏아이코닉럭비셔츠-옐로우',
#  '베이식피케폴로셔츠[네이비]',
#  '엔젤카라롱슬리브카키',
#  '슬릿넥피케폴로셔츠[머쉬룸]',
#  '오픈칼라폴로셔츠[네이비]',
#  '10/6배송[ASIA]긴팔카라6.2ozRuggerShirt(BLACK)CKTS1F924BK',
#  '남성오렌지레터링프린팅칼라티셔츠(BJ1941B078)',
#  '10/8배송[Men]부클레폴로니트_KhakiBeige',
#  '10/8배송[Men]부클레폴로니트_Cream',
#  '10/8배송[Men]부클레폴로니트_ForestGreen',
#  '[NDL라인]여성화이트칼라배색기모이너티셔츠(BJ1941L531)',
#  '로고저지폴로셔츠화이트',
#  '패치저지폴로셔츠시그니쳐라벨',
#  '클래식저지폴로셔츠네이비',
#  '로고저지폴로셔츠그레이',
#  '클래식저지폴로셔츠워시드그레이',
#  '쿨소프트숏슬리브카라니트블루',
#  '21S/S오버핏피케티셔츠(라이트카키)',
#  '폴로셔츠니트[아이보리]',
#  '폴로셔츠니트[브라운]',
#  'OGPIGMENTDYEINGRUGBYTEE_PINK',
#  '피케카라리브드니트_아이보리',
#  'EMB오픈카라스트라이프니트_네이비',
#  '남성애쉬보더스트라이프기모칼라티셔츠(BJ1941B044)',
#  '남성네이비보더스트라이프기모칼라티셔츠(BJ1941B04R)',
#  'CollarRibPulloverBLACK(JYSW1D910BK)',
#  'Decode더게임폴로티1366260-100',
#  'TA-144루즈핏피케롱슬리브_BK',
#  '아이소칠BOF폴로티1366249-001',
#  'POLOSWEATSHIRT_MELANGEGRAY',
#  '피케카라스웨터_모카',
#  '피케카라스웨터_베이지',
#  'DRILLKNITSWEATER(BROWN)',
#  '릴렉스핏피케폴로셔츠[화이트]',
#  '[NDL라인]여성블랙시그니처백기모칼라티셔츠(BJ1941L515)',
#  'EMB오픈카라스트라이프니트_베이지',
#  '오픈카라티셔츠[D.GREY]',
#  '피케카라리브드니트_베이지',
#  '실켓긴소매카라티셔츠[차콜]',
#  '오픈카라니트탑_아이보리',
#  'DRILLKNITSWEATER(BLACK)',
#  '[UNISEX]플라워도트자수화이트클립피케반팔티셔츠_블랙',
#  'POLOSWEATSHIRT_BLACK',
#  '인베스트인골프폴로티셔츠BLACK(WOMAN)',
#  'OSLOGORUGBYTEE_NAVY',
#  '커스텀슬림핏메시폴로-블랙',
#  '10/6배송flowerknitpolomtm(green)',
#  'flowerknitpolomtm(beige)',
#  '10/8배송[Woman]부클레폴로니트_Cream',
#  '10/8배송[Woman]부클레폴로니트_ForestGreen',
#  '10/8배송[Woman]부클레폴로니트_KhakiBeige',
#  '폴로티네이비/K570-NVY',
#  '10/6배송flowerknitpolomtm(black)',
#  'WaffleCollarPolo-Dove',
#  '10/18배송머튜얼반집업카라니트_MidnightBlue',
#  'WIDECOLLAR-TWHITE',
#  '10/7배송HERITAGEHANDSOMEDANKNITPKSHIRTGRAY',
#  '피케맨투맨크림',
#  '인베스트인골프폴로티셔츠BLUE(WOMAN)',
#  'WIDECOLLAR-TBLACK',
#  '10/7배송HERITAGEHANDSOMEDANKNITPKSHIRTCHECKER',
#  '카라오버니트그레이',
#  '10/6배송[ASIA]긴팔카라6.2ozRuggerShirt(NORMALRED)CKTS1F924R2',
#  '베이식피케폴로셔츠[더스티베이지]',
#  '10/6배송[ASIA]긴팔카라6.2ozRuggerShirt(CHARCOALGREY)CKTS1F924CG',
#  '와플카라티셔츠블랙',
#  '네이비브러시드숄칼라티셔츠(BC1941C20R)',
#  '와플카라티셔츠크림',
#  '오픈카라티셔츠[DUSTYCREAM]',
#  '인베스트인골프폴로티셔츠WHITE(WOMAN)',
#  '아이보리브러시드숄칼라티셔츠(BC1941C200)',
#  '[홀리데이세일]폴로셔츠니트[블루]',
#  '[NDL라인]여성네이비칼라배색기모이너티셔츠(BJ1941L53R)',
#  '카라오버니트블랙',
#  '[NDL라인]여성화이트시그니처백기모칼라티셔츠(BJ1941L511)',
#  '[NDL라인]여성그린칼라배색기모이너티셔츠(BJ1941L53M)',
#  '카라오버니트베이지',
#  '골프남성긴팔카라티셔츠(O/WHITE)',
#  '10/18배송머튜얼클래식카라니트_WalnutBrown',
#  '슬릿넥피케폴로셔츠[다크그레이]',
#  '남성포인트라인긴팔티셔츠_WMTBX21990BKX',
#  '골프남성긴팔카라티셔츠(L/MINT)',
#  'EMBROIDERYHANDSOMEDANPKSHIRTBLACK',
#  '10/18배송머튜얼클래식카라니트_SandBeige',
#  '롤리팝스트라이프니트풀오버(레드)',
#  '롤리팝스트라이프니트풀오버(옐로우)',
#  'comfortablechetopktshirts',
#  '캠퍼스카라맨투맨네이비',
#  '새벽배송남성레드하트와펜폴로셔츠-화이트/P1T0065(AZT0065)',
#  'UNBALANCEDCOLLART-SHIRT(PURPLENAVY)',
#  'UNBALANCEDCOLLART-SHIRT(NAVY)',
#  '새벽배송남성블랙하트와펜폴로셔츠-화이트/P1T0662(AZT0662)',
#  '10/18배송머튜얼클래식카라니트_Black',
#  '커스텀슬림핏메시폴로-블루',
#  '브이컬러블락럭비티셔츠_브라운',
#  '브이컬러블락럭비티셔츠_네이비',
#  '오픈칼라폴로셔츠[화이트]',
#  '커스텀슬림핏메시폴로-화이트',
#  '[쿨탠다드]쿨탠다드피케폴로셔츠[화이트]',
#  '오픈카라피케루즈핏반팔티(BLACK)',
#  '스트라이프럭비셔츠[블랙/아이보리]',
#  '오픈카라티셔츠[KHAKIGREY]',
#  '남성포인트배색긴팔피케티셔츠그린HF-KT2002GR',
#  '남성포인트배색긴팔피케티셔츠네이비HF-KT2002NY',
#  '피케폴로셔츠-블랙',
#  '335-ALP드라이폴로긴팔셔츠블랙',
#  '캠퍼스카라맨투맨오트밀',
#  '[세트구성]폴로셔츠니트[6color]',
#  '베이식피케폴로셔츠[화이트]',
#  '슬릿넥피케폴로셔츠[화이트]',
#  '폴로셔츠니트[그린]',
#  '슬림카라티(라이트그레이)(블랙)',
#  '오버핏카라스웨터(아이보리)',
#  '오버핏카라스웨터(검정)',
#  '무지모달머슬핏폴로셔츠(블랙)',
#  '캠퍼스카라맨투맨그레이',
#  '오픈카라피케루즈핏반팔티(BROWN)',
#  '[우먼즈]코튼크롭폴로셔츠-화이트',
#  '오픈카라피케루즈핏반팔티(GREYISHGREEN)',
#  'WafflePoloCharcoal',
#  '10/7배송TA-144루즈핏피케롱슬리브_CR',
#  'BorisKnittedShirtsinMelangeBlack',
#  '21S/S오버핏피케티셔츠(그레이블루)',
#  'AdjustableWaistCollarSweatshirt_L4TAW21031IVX',
#  '피케폴로셔츠-화이트',
#  '시그니처V-카라티셔츠[화이트]',
#  '여성카라슬림스웨터-AFRG5251C03',
#  '폴로셔츠니트[라이트그레이]',
#  '시그니처V-카라티셔츠[블랙]',
#  '여성카라슬림스웨터-AFRG5251C0U',
#  'StripedRugbyShirtBurgundy',
#  '여성카라슬림스웨터-AFRG5251C0G',
#  '오픈칼라폴로셔츠[더스티베이지]',
#  'AdjustableWaistCollarSweatshirt_L4TAW21031BKX',
#  '오버사이즈피케스웨트셔츠그레이지',
#  'EMBROIDERYHANDSOMEDANPKSHIRTNAVY',
#  '오픈칼라폴로셔츠[머쉬룸]',
#  '세미오버핏오픈카라반팔티블랙',
#  '플레인폴로셔츠[더스티카키]',
#  '엔젤카라긴팔니트블랙',
#  '오버사이즈피케스웨트셔츠그레이쉬블루',
#  'FlowerEmbroideredHalfZip-upTShirt-Cream',
#  '더블엔젤카라맨투맨블랙',
#  'FlowerEmbroideredHalfZip-upTShirt-Chacoal',
#  'StripeCropRugbyShirt(2color)',
#  'NGRDLONGPIQUESHIRTS-CHARCOAL',
#  '오픈카라티셔츠[MOCHA]',
#  'NGRDLONGPIQUESHIRTS-BURGUNDY',
#  '[패키지]루즈핏카라티셔츠패키지JKST2066',
#  '10/5배송그레이오버핏화섬패치더블포켓카라티',
#  '10/5배송블랙오버핏화섬패치더블포켓카라티',
#  '골프여성긴팔카라티셔츠(O/WHITE)',
#  '슬림카라티(퍼플)',
#  '트리플폭스패치폴로반팔티셔츠',
#  '슬릿넥피케폴로셔츠[네이비]',
#  '10/6배송VelourCollarT-Shirts(Black)',
#  'WafflePoloGrey',
#  '10/5배송[ASIA]Golf남성C로고폴로셔츠(DARKNAVY)CKTS1F001N3',
#  '피그먼트다이칼라맨투맨PIGMENTDYECOLLARMTM',
#  '남성시그니처폴로긴팔티셔츠_WMTBW21701BUX',
#  '릴렉스핏피케폴로셔츠[다크그레이]',
#  '파리생제르맹슬림폴로반팔티(화이트)',
#  '슬릿넥니티드폴로셔츠[블랙]',
#  'YOKO에리포인트로고여성긴팔티셔츠[WHITE]',
#  'YOKO에리포인트로고여성긴팔티셔츠[BROWN]',
#  '플레인폴로셔츠[머쉬룸]',
#  '롱슬리브피케폴로셔츠[화이트]',
#  '21S/S오버핏피케티셔츠(아보카도)',
#  '시그니처긴팔폴로WHITESAND',
#  '스트라이프오버럭비티셔츠_BrownNavy',
#  '오픈카라티셔츠[BROWN]',
#  '베이직립폴라니트(베이지)',
#  '시그니처긴팔폴로DARKBLACKPLUM',
#  '베이식피케폴로셔츠[카키]',
#  '머튜얼클래식카라니트_Cream',
#  '베이식피케폴로셔츠[다크그레이]',
#  '럭비스트라이프티셔츠아이보리',
#  '335-ALP드라이폴로긴팔셔츠네이비',
#  '리브드오픈칼라니트_Black',
#  '10/5배송[ASIA]Golf여성C로고피케반팔티셔츠(DARKNAVY)CKTS1F070N3',
#  '10/5배송[ASIA]Golf여성C로고피케반팔티셔츠(WHITE)CKTS1F070WT',
#  '레터링쿨메쉬폴로셔츠',
#  '메종라이닝포인트티셔츠_BK',
#  ...]

# %% [markdown]
# # 올바른 가격 정보 가져오기(세일 가격이면 세일가격으로)

# %%
url="https://search.musinsa.com/category/002012"
html= urlopen(url)
bs= BeautifulSoup(html, "html.parser")
ex_price=[]
for item_price in bs.find_all('p',{"class":"price"}):
    ex_price.append(no_space(item_price.get_text()))

# %%
for i in range(len(ex_price)):
    ex_price[i]=ex_price[i].replace(" ", "")

# %%
ex_price
# Out:
# ['149,000원129,000원',
#  '339,000원179,000원',
#  '119,900원',
#  '119,900원',
#  '359,000원251,300원',
#  '111,700원89,900원',
#  '119,900원71,890원',
#  '359,000원251,300원',
#  '249,000원',
#  '124,000원99,000원',
#  '249,000원',
#  '89,000원44,500원',
#  '298,000원',
#  '298,000원',
#  '339,000원179,000원',
#  '398,000원318,400원',
#  '238,000원',
#  '238,000원',
#  '229,000원',
#  '139,000원',
#  '139,000원',
#  '228,000원69,000원',
#  '198,000원69,000원',
#  '228,000원69,000원',
#  '228,000원69,000원',
#  '228,000원69,000원',
#  '359,000원',
#  '359,000원',
#  '359,000원',
#  '359,000원',
#  '198,000원69,000원',
#  '219,000원',
#  '219,000원',
#  '319,000원',
#  '219,000원',
#  '249,000원224,100원',
#  '219,000원',
#  '219,000원',
#  '328,000원',
#  '239,000원',
#  '219,000원',
#  '169,000원',
#  '179,000원',
#  '169,000원',
#  '179,000원',
#  '249,000원211,650원',
#  '169,000원',
#  '239,000원',
#  '359,000원',
#  '69,900원59,900원',
#  '249,000원211,650원',
#  '359,000원',
#  '169,000원',
#  '259,000원248,600원',
#  '259,000원248,600원',
#  '399,000원159,600원',
#  '124,000원99,000원',
#  '329,000원',
#  '239,000원',
#  '159,000원143,100원',
#  '340,000원295,000원',
#  '279,000원',
#  '249,000원224,100원',
#  '89,900원',
#  '179,000원152,150원',
#  '149,000원129,000원',
#  '219,000원109,500원',
#  '209,000원189,000원',
#  '86,000원59,000원',
#  '69,900원',
#  '69,900원',
#  '99,000원84,150원',
#  '86,000원59,000원',
#  '189,000원179,000원',
#  '219,000원',
#  '179,000원152,150원',
#  '159,000원143,100원',
#  '240,000원210,000원',
#  '124,100원86,900원',
#  '159,000원99,000원',
#  '240,000원210,000원',
#  '240,000원210,000원',
#  '370,000원325,000원',
#  '129,000원',
#  '89,800원',
#  '299,000원269,000원',
#  '240,000원210,000원',
#  '360,000원315,000원',
#  '350,000원305,000원',
#  '239,000원215,100원']

# %%
for i in ex_price:
  a=i.replace(" ",'')
  b=a.replace("원", '.')
  c=b.split('.')
  if len(c)>2:
    print(c[1])
  else:
    print(c[0])
# Out:
# 129,000
# 179,000
# 119,900
# 119,900
# 251,300
# 89,900
# 71,890
# 251,300
# 249,000
# 99,000
# 249,000
# 44,500
# 298,000
# 298,000
# 179,000
# 318,400
# 238,000
# 238,000
# 229,000
# 139,000
# 139,000
# 69,000
# 69,000
# 69,000
# 69,000
# 69,000
# 359,000
# 359,000
# 359,000
# 359,000
# 69,000
# 219,000
# 219,000
# 319,000
# 219,000
# 224,100
# 219,000
# 219,000
# 328,000
# 239,000
# 219,000
# 169,000
# 179,000
# 169,000
# 179,000
# 211,650
# 169,000
# 239,000
# 359,000
# 59,900
# 211,650
# 359,000
# 169,000
# 248,600
# 248,600
# 159,600
# 99,000
# 329,000
# 239,000
# 143,100
# 295,000
# 279,000
# 224,100
# 89,900
# 152,150
# 129,000
# 109,500
# 189,000
# 59,000
# 69,900
# 69,900
# 84,150
# 59,000
# 179,000
# 219,000
# 152,150
# 143,100
# 210,000
# 86,900
# 99,000
# 210,000
# 210,000
# 325,000
# 129,000
# 89,800
# 269,000
# 210,000
# 315,000
# 305,000
# 215,100

# %%
for i in range(len(ex_price)):
    if len(ex_price[i].split('원'))> 2:
        ex_price[i]=ex_price[i].split('원')[1]

# %%
for i in range(len(ex_price)):
    numbers = re.sub(r'[^0-9]', '', ex_price[i])
    print(numbers)
# Out:
# 11900
# 13900
# 19500
# 11900
# 34400
# 10900
# 35000
# 24500
# 17800
# 19500
# 18000
# 19900
# 10900
# 12900
# 21000
# 23400
# 29700
# 28800
# 19500
# 10000
# 23400
# 19900
# 21500
# 21000
# 14900
# 23400
# 21000
# 21800
# 37800
# 17900
# 25350
# 21000
# 25350
# 21000
# 15900
# 21000
# 17900
# 12900
# 15900
# 23400
# 23400
# 23400
# 21000
# 25350
# 21900
# 19500
# 8900
# 39800
# 32000
# 18900
# 15600
# 21000
# 39000
# 24500
# 11900
# 24500
# 27600
# 21900
# 23400
# 24500
# 9900
# 39000
# 23400
# 27900
# 24500
# 11890
# 23400
# 23400
# 39000
# 16800
# 21900
# 28000
# 24000
# 27300
# 15990
# 39000
# 35900
# 11900
# 14900
# 25350
# 25900
# 42900
# 15600
# 19900
# 28700
# 29000
# 11900
# 19500
# 23100
# 28050

# %% [markdown]
# # AWS RDS에 접속하여 쿼리 보내기

# %%
query=[]
for j in range(len(item_name_list)):
    query.append("INSERT INTO products(name,brand, price, type) VALUES('"+ item_name_list[j]+"','"+item_brand_list[j]+"',"+item_price_list[j].replace(',','')+", '"+ item_type_list[j]+"');")

# %%
import pymysql
db = pymysql.connect(host='musinsa-database.crtzc6j6k6ch.ap-northeast-2.rds.amazonaws.com', user='admin', password='wnstjr96', port=3306, db='musinsa')
cursor= db.cursor()
for j in range(len(query)):
    sql=query[j]
    cursor.execute(sql)
result=cursor.fetchall()
print(result)
db.commit()
db.close
# Out:
# ()
# <bound method Connection.close of <pymysql.connections.Connection object at 0x000002EA74F4AB20>>

# %%
print(query[:10])
# Out:
# ["INSERT INTO products(name,brand, price, type) VALUES('레이어드크루넥반팔티셔츠_긴기장[화이트]','무신사 스탠다드',13900, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('릴렉스핏크루넥반팔티셔츠[화이트]','무신사 스탠다드',11900, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('베이식크루넥반팔티셔츠[화이트]','무신사 스탠다드',10900, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('릴렉스핏크루넥반팔티셔츠[블랙]','무신사 스탠다드',11900, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('EMBROIDERYHANDSOMEDANTEEWHITE','예일',27300, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('021541레이어드반팔티셔츠(2pck)','지오다노',18000, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('쿨코튼2-PACK티셔츠','커버낫',34400, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('[패키지]NYCLOCATIONT-SHIRT(16Colors)[LRPMCTA401M]','그루브라임',35000, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('020940레이어드반팔티','지오다노',12800, '반팔 티셔츠');", "INSERT INTO products(name,brand, price, type) VALUES('[세트상품]더블코튼롱티셔츠','어커버',17800, '반팔 티셔츠');"]
